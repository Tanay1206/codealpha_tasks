# %%
import pandas as pd
df = pd.read_csv("MyAnimeList_TopAnime.csv")
df.head()
# Out:
#    Rank                                     Title  Score
# 0     1                         Sousou no Frieren   9.27
# 1     2  Steel Ball Run: JoJo no Kimyou na Bouken   9.14
# 2     3          Fullmetal Alchemist: Brotherhood   9.11
# 3     4              Chainsaw Man Movie: Reze-hen   9.08
# 4     5                               Steins;Gate   9.07

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Rank    50 non-null     int64
#  1   Title   50 non-null     str
#  2   Score   50 non-null     float64
# dtypes: float64(1), int64(1), str(1)
# memory usage: 1.3 KB

# %%
df.isnull().sum()
# Out:
# Rank     0
# Title    0
# Score    0
# dtype: int64

# %%
df.describe()
# Out:
#            Rank      Score
# count  50.00000  50.000000
# mean   25.50000   8.907000
# std    14.57738   0.119987
# min     1.00000   8.750000
# 25%    13.25000   8.820000
# 50%    25.50000   8.895000
# 75%    37.75000   9.002500
# max    50.00000   9.270000

# %%
high_score_rule = df['Score'] > 9.10

# %%
masterpieces = df[high_score_rule]
masterpieces
# Out:
#    Rank                                     Title  Score
# 0     1                         Sousou no Frieren   9.27
# 1     2  Steel Ball Run: JoJo no Kimyou na Bouken   9.14
# 2     3          Fullmetal Alchemist: Brotherhood   9.11

# %%
import matplotlib.pyplot as plt

top_10 = df.head(10)

plt.figure(figsize=(10, 6))

plt.barh(top_10['Title'], top_10['Score'], color='skyblue')

plt.xlabel('MAL Score')
plt.ylabel('Anime Title')
plt.title('Top 10 Highest Rated Anime')

plt.gca().invert_yaxis()

plt.show()
